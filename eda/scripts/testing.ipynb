# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
from matplotlib import cm

from data_loader import load_and_adapt_simulation_data
from visualization import visualize_entering_stats_multi, visualize_speed_heatmap
from physics_analysis import analyze_stopping_deceleration, analyze_acceleration_phases, analyze_standstill_distances

# %%
# csv path -> df
sim_path = '../data/drift/drone_5.csv'
sim_df = load_and_adapt_simulation_data(sim_path)
img_path = '../data/media/SiteA.jpg'
# Out:
# Loading simulation data from ../data/drift/drone_5.csv...
# Adapted data: 53264 rows.

# %%
visualize_entering_stats_multi(sim_df, img_path)
# Out:
# Processing 1 sessions...
# =======================================================
# AGGREGATED TRAFFIC STATS (Total Duration: 41.17s)
# =======================================================
# Lane       | Side       | Total Count  | Freq (cars/s)
# ------------------------------------------------------------
# Lane 1     | Left       | 1            | 0.0243
# Lane 3     | Top        | 3            | 0.0729
# Lane 4     | Top        | 1            | 0.0243
# Lane 5     | Top        | 2            | 0.0486
# Lane 6     | Right      | 6            | 0.1457
# Lane 7     | Right      | 11           | 0.2672
# Lane 8     | Right      | 10           | 0.2429
# ============================================================

# %%
visualize_speed_heatmap(sim_df, img_path)
# Out:
# Calculating speeds across sessions...
# Computed speeds for 53163 points. Avg Speed: 8.85 m/s

# %%
analyze_stopping_deceleration(sim_df)
analyze_acceleration_phases(sim_df)
analyze_standstill_distances(sim_df)
# Out:
# Analyzing continuous deceleration phases...
# Analyzed 12557 data points of braking.
# Average Deceleration: 2.58 m/s²
# Median Deceleration: 2.34 m/s²
# 95th Percentile (Hard Braking): 5.35 m/s²
# Analyzing continuous acceleration phases...
# Analyzed 15124 data points of acceleration.
# Average Acceleration: 2.45 m/s²
# Median Acceleration: 2.32 m/s²
# 95th Percentile: 4.63 m/s²
# Analyzing standstill distances...
# Analyzed 109 stopped pairs.
# Avg Center-to-Center: 10.65 m (Median: 10.08 m)
# Avg Bumper-to-Bumper: 2.98 m (Median: 2.67 m)
